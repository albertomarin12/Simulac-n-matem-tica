 434, 512, 598, 373, 239, 282, 378, 410, 446, 335, 225, 232, 396, 329, 388, 229, 352, 266, 256, 312, 286, 257, 198, 202, 322, 81, 143, 222, 159, 105, 102, 128, 70, 84, 86, 92, 94, 98, 53, 48, 69, 62, 34, 68, 49, 49, 45, 4, 59, 73, 32, 44, 37, 33, 41, 27, 42, 35, 19, 16, 43, 16, 12, 13, 24, 10, 37, 18, 2, 6, 12, 2, 11, 6, 3, 6, 6, 5, 0, 3, 9, 3, 3, 4, 12, 5, 1, 4, 7, 1, 5, 13, 9, 7, 0, 5, 9, 8.])

# %% [markdown]
# Éstos corresponden a los contagios diarios de COVID-19 a partir del 22 de marzo del 2020 al 6 de agosto del 2021.
#
# Ordene los datos en un DataFrame de pandas correspondiendo fecha con numero de contagios.

# %%
fechas = pd.date_range("2020-03-22", "2021-08-06")
D = pd.DataFrame(index=fechas, data=D, columns=["Contagios"])
D
# Out:
#             Contagios
# 2020-03-22     1685.0
# 2020-03-23     1647.0
# 2020-03-24     1500.0
# 2020-03-25     1545.0
# 2020-03-26     1710.0
# ...               ...
# 2021-08-02        7.0
# 2021-08-03        0.0
# 2021-08-04        5.0
# 2021-08-05        9.0
# 2021-08-06        8.0
#
# [503 rows x 1 columns]

# %%
D = D[(D['Contagios']> 0)]
D
# Out:
#             Contagios
# 2020-03-22     1685.0
# 2020-03-23     1647.0
# 2020-03-24     1500.0
# 2020-03-25     1545.0
# 2020-03-26     1710.0
# ...               ...
# 2021-08-01        9.0
# 2021-08-02        7.0
# 2021-08-04        5.0
# 2021-08-05        9.0
# 2021-08-06        8.0
#
# [501 rows x 1 columns]

# %%
D.describe()
# Out:
#          Contagios
# count   501.000000
# mean    575.884232
# std     469.118546
# min       1.000000
# 25%     198.000000
# 50%     506.000000
# 75%     766.000000
# max    2148.000000

# %% [markdown]
# Calcule la variación relativa día a día que mejor se aproxime a una distrubución normal

# %%
D.shift()
# Out:
#             Contagios
# 2020-03-22        NaN
# 2020-03-23     1685.0
# 2020-03-24     1647.0
# 2020-03-25     1500.0
# 2020-03-26     1545.0
# ...               ...
# 2021-08-01       13.0
# 2021-08-02        9.0
# 2021-08-04        7.0
# 2021-08-05        5.0
# 2021-08-06        9.0
#
# [501 rows x 1 columns]

# %%
R = (D - D.shift())/D.shift()
r = np.log(D/D.shift())

r.plot.hist(alpha = 0.5)
R.plot.hist(alpha = 0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
r.describe()
# Out:
#         Contagios
# count  500.000000
# mean    -0.010700
# std      0.380650
# min     -2.420368
# 25%     -0.093791
# 50%     -0.008589
# 75%      0.072892
# max      2.691243

# %%
R.describe()
# Out:
#         Contagios
# count  500.000000
# mean     0.076157
# std      0.762304
# min     -0.911111
# 25%     -0.089527
# 50%     -0.008552
# 75%      0.075615
# max     13.750000

# %%
R_mean = R.mean()
R_std = R.std()
R_mean
# Out:
# Contagios    0.076157
# dtype: float64

# %%
np.random.seed(2)
R_D_simulados = np.random.normal(R_mean, R_std, 5) # 10 simulaciones, simulando 5 días
R_D_simulados
# Out:
# array([-0.24153981,  0.03326409, -1.55227517,  1.32654221, -1.29098732])

# %% [markdown]
# Simule 10000 escenarios para el siguiente año y calcule la probabilidad de que los contagios sean menores que 50.

# %%
def sim_r(media, std, inicio, dias, N):
    # media 
    # desviación estándar
    # desde qué fecha inicio a simular
    # cuántos días voy a simular
    # N: cuántas simulaciones
    r = np.random.normal(media, std, size=(dias, N))
    fechas = pd.date_range(inicio, periods=dias)
    return pd.DataFrame(index = fechas, data = r)
r_simulados = sim_r(R_mean, R_std, "2021-08-06", 365, 10000)

# %%
(r_simulados + 1).cumprod()*D["Contagios"][-1] # r_simulados son cumprod es producto acumulado
# Out:
#                     0             1             2             3     \
# 2021-08-06  4.084701e+00  6.304640e+00  1.022110e+01  7.245056e+00
# 2021-08-07  4.971375e+00  4.477836e+00  1.720627e+00  6.360254e+00
# 2021-08-08  2.350613e+00  5.384083e+00  6.032397e-02  8.561218e+00
# 2021-08-09  1.658237e+00  7.900223e+00  8.611221e-02  9.384205e+00
# 2021-08-10  1.786854e+00  9.752870e+00  1.292164e-01  1.222450e+01
# ...                  ...           ...           ...           ...
# 2022-08-01 -7.906636e-19 -7.570588e-19  7.526377e-24  1.659695e-20
# 2022-08-02 -8.655343e-19 -7.760770e-19 -8.120461e-26  4.347317e-21
# 2022-08-03 -2.063770e-18 -1.556282e-18 -8.234604e-26  8.654021e-21
# 2022-08-04 -9.384411e-19 -8.189700e-19 -8.888124e-26  3.614162e-21
# 2022-08-05 -3.958457e-19 -1.139115e-18 -1.329952e-26  5.346183e-21
#
#                     4             5             6             7     \
# 2021-08-06 -1.107544e-01  1.649194e+01  1.142435e+01  6.086595e+00
# 2021-08-07 -2.916864e-02  1.995539e+01  7.059812e+00  4.708583e+00
# 2021-08-08  3.074055e-02  3.386905e+01  1.227143e+01  1.788117e+00
# 2021-08-09  5.040888e-02  5.569439e+01  1.820659e+01  1.480351e+00
# 2021-08-10 -6.469100e-03  5.552009e+01  1.952927e+01 -1.093959e-01
# ...                  ...           ...           ...           ...
# 2022-08-01 -1.578439e-37 -8.843114e-30 -1.260271e-22 -9.218351e-15
# 2022-08-02 -6.255875e-38 -1.045754e-29 -3.062735e-22 -3.236772e-15
# 2022-08-03 -8.638225e-38 -9.465334e-30 -2.842458e-22 -2.372245e-15
# 2022-08-04 -4.485433e-38 -1.100483e-29 -1.558658e-22  1.010221e-15
# 2022-08-05 -4.422328e-38  4.273414e-30  1.135532e-22  3.511338e-16
#
#                     8             9     ...          9990          9991  \
# 2021-08-06  1.375621e+01  7.731851e+00  ...  1.785467e+01  2.056238e+01
# 2021-08-07  1.800974e+01  1.055159e+01  ...  2.818795e+01  8.877250e+00
# 2021-08-08  2.889452e+01  7.844062e+00  ...  5.572931e+00  5.172555e+00
# 2021-08-09  5.026516e+01  6.103462e+00  ...  1.176076e+01  8.422870e+00
# 2021-08-10  2.239450e+01  6.340486e+00  ...  3.475514e+01  1.084488e+01
# ...                  ...           ...  ...           ...           ...
# 2022-08-01  6.872063e-28  3.119527e-23  ...  4.020495e-13 -2.270553e-15
# 2022-08-02  3.100692e-28 -7.902991e-24  ...  6.320272e-13 -4.145738e-15
# 2022-08-03  5.552201e-28 -1.314481e-23  ... -1.634960e-13 -7.452352e-15
# 2022-08-04  6.558456e-28 -2.048837e-23  ... -1.195937e-13 -5.763730e-15
# 2022-08-05  3.698340e-28 -6.999420e-24  ... -1.217613e-13  7.874552e-15
#
#                     9992          9993          9994          9995  \
# 2021-08-06  1.331630e+01  7.572319e+00  1.504777e+01  5.075994e+00
# 2021-08-07  5.874566e+00  8.553547e+00  7.749420e+00  7.868229e+00
# 2021-08-08  4.234858e+00  3.179778e+00  7.786973e+00  1.074219e+01
# 2021-08-09  4.332124e+00  5.749410e+00  1.510424e+01  6.707674e+00
# 2021-08-10  7.577473e+00  5.241202e+00  1.714830e+01  1.079495e+01
# ...                  ...           ...           ...           ...
# 2022-08-01  8.685149e-27 -4.706620e-31  6.667473e-38  1.127620e-30
# 2022-08-02  1.949165e-26 -1.118832e-30  4.799020e-38  4.799549e-31
# 2022-08-03  1.741483e-26 -1.713640e-30  8.965531e-38  6.954530e-31
# 2022-08-04 -7.937922e-27  1.651636e-33  7.424658e-38  1.114566e-30
# 2022-08-05 -8.503373e-27  8.272507e-34 -2.340118e-38  7.665223e-31
#
#                     9996          9997          9998          9999
# 2021-08-06  1.317245e+01  6.912301e+00  5.039211e+00  1.717811e+01
# 2021-08-07  1.141532e+01  1.507730e+01  8.445404e+00  1.832443e+01
# 2021-08-08  2.767539e+00  1.265147e+01  9.217757e+00  1.279986e+01
# 2021-08-09  3.553534e+00  1.608104e+01  8.870252e+00  1.053431e+00
# 2021-08-10  6.515693e+00  8.390411e+00  8.933613e+00  1.313217e+00
# ...                  ...           ...           ...           ...
# 2022-08-01  3.969393e-34 -8.416527e-25 -3.271142e-19  5.774297e-25
# 2022-08-02  2.363531e-34 -2.090787e-24 -3.392827e-19  1.297205e-24
# 2022-08-03  2.445354e-35 -4.828974e-24  1.300862e-19 -8.074839e-25
# 2022-08-04  6.456038e-36 -4.181796e-24  1.403052e-19 -2.306623e-24
# 2022-08-05  9.371688e-36 -1.867708e-24  2.246662e-19 -5.948156e-24
#
# [365 rows x 10000 columns]

# %%
precios_simulados = (r_simulados + 1).cumprod()*D["Contagios"][-1]
#precios_simulados.plot()

# %%
valor_deseado = 50
probabilidad = (precios_simulados <= valor_deseado).mean(axis=1)

plt.figure()
plt.plot(probabilidad)
plt.grid()

# %%
probabilidad
# Out:
# 2021-08-06    1.0000
# 2021-08-07    0.9967
# 2021-08-08    0.9724
# 2021-08-09    0.9479
# 2021-08-10    0.9282
#                ...
# 2022-08-01    0.9999
# 2022-08-02    0.9999
# 2022-08-03    0.9999
# 2022-08-04    0.9999
# 2022-08-05    0.9999
# Freq: D, Length: 365, dtype: float64
